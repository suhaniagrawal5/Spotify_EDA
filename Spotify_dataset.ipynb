# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('spotify_tracks.csv')
df.head()
# Out:
#                        id                                           name  \
# 0  7kr3xZk4yb3YSZ4VFtg2Qt                                       Acoustic
# 1  1kJygfS4eoVziBBI93MSYp                                       Acoustic
# 2  6lynns69p4zTCRxmmiSY1x                  Here Comes the Sun - Acoustic
# 3  1RC9slv335IfLce5vt9KTW                                    Acoustic #3
# 4  5o9L8xBuILoVjLECSBi7Vo  My Love Mine All Mine - Acoustic Instrumental
#
#       genre                        artists  \
# 0  acoustic                  Billy Raffoul
# 1  acoustic                  Billy Raffoul
# 2  acoustic  Molly Hocking, Bailey Rushlow
# 3  acoustic              The Goo Goo Dolls
# 4  acoustic  Guus Dielissen, Casper Esmann
#
#                                            album  popularity  duration_ms  \
# 0                                           1975        58.0     172199.0
# 1                        A Few More Hours at YYZ        57.0     172202.0
# ...

# %%
df.drop(columns='duration_ms')
df.head()
# Out:
#                        id                                           name  \
# 0  7kr3xZk4yb3YSZ4VFtg2Qt                                       Acoustic
# 1  1kJygfS4eoVziBBI93MSYp                                       Acoustic
# 2  6lynns69p4zTCRxmmiSY1x                  Here Comes the Sun - Acoustic
# 3  1RC9slv335IfLce5vt9KTW                                    Acoustic #3
# 4  5o9L8xBuILoVjLECSBi7Vo  My Love Mine All Mine - Acoustic Instrumental
#
#       genre                        artists  \
# 0  acoustic                  Billy Raffoul
# 1  acoustic                  Billy Raffoul
# 2  acoustic  Molly Hocking, Bailey Rushlow
# 3  acoustic              The Goo Goo Dolls
# 4  acoustic  Guus Dielissen, Casper Esmann
#
#                                            album  popularity  duration_ms  \
# 0                                           1975        58.0     172199.0
# 1                        A Few More Hours at YYZ        57.0     172202.0
# ...

# %%
df['explicit'].dtype
# Out:
# dtype('int32')

# %%
df.drop(columns='duration_ms')
# Out:
#                           id                                           name  \
# 0     7kr3xZk4yb3YSZ4VFtg2Qt                                       Acoustic
# 1     1kJygfS4eoVziBBI93MSYp                                       Acoustic
# 2     6lynns69p4zTCRxmmiSY1x                  Here Comes the Sun - Acoustic
# 3     1RC9slv335IfLce5vt9KTW                                    Acoustic #3
# 4     5o9L8xBuILoVjLECSBi7Vo  My Love Mine All Mine - Acoustic Instrumental
# ...                      ...                                            ...
# 6297  56pHPaTeX2O9aVmTFYS8hV                                   The Daintree
# 6298  6Ldyc5TsR4kaUsuHKcB2AD                         The Sorcerers Symphony
# 6299  3ry0f8ybk8upUBIk8unvmF                                Fiore d'inverno
# 6300                     NaN                                            NaN
# 6301                     NaN                                            NaN
#
#             genre                        artists  \
# ...

# %%
df['genre'].unique()
# Out:
# array(['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient',
#        'anime', 'black-metal', 'bluegrass', 'blues', 'bossanova',
#        'brazil', 'breakbeat', 'british', 'cantopop', 'chicago-house',
#        'children', 'chill', 'classical', 'club', 'comedy', 'country',
#        'dance', 'dancehall', 'death-metal', 'deep-house',
#        'detroit-techno', 'disco', 'disney', 'drum-and-bass', 'dub',
#        'dubstep', 'edm', 'electro', 'electronic', 'emo', 'folk', 'forro',
#        'french', 'funk', 'garage', 'german', 'gospel', 'goth',
#        'grindcore', 'groove', 'grunge', 'guitar', 'happy', 'hard-rock',
#        'hardcore', 'hardstyle', 'heavy-metal', 'hip-hop', 'holidays',
#        'honky-tonk', 'house', 'idm', 'indian', 'indie', 'indie-pop',
#        'industrial', 'iranian', 'j-dance', 'j-idol', 'j-pop', 'j-rock',
#        'jazz', 'k-pop', 'kids', 'latin', 'latino', 'malay', 'mandopop',
#        'metal', 'metal-misc', 'metalcore', 'minimal-techno', 'movies',
# ...

# %%
df['album'].unique()
# Out:
# array(['1975', 'A Few More Hours at YYZ', 'Here Comes the Sun (Acoustic)',
#        ..., 'Africa Essential of African Music',
#        'World Party 5 by Putumayo', nan], dtype=object)

# %%
df['artists'].unique()
# Out:
# array(['Billy Raffoul', 'Molly Hocking, Bailey Rushlow',
#        'The Goo Goo Dolls', ...,
#        'Putumayo, Marianne Perrudin, Thomas Artaud',
#        'Putumayo, Giacomo Lariccia', nan], dtype=object)

# %%
df2 =df.drop(columns='explicit')
df3=df2.drop(columns='duration_ms')
df3
# Out:
#                           id                                           name  \
# 0     7kr3xZk4yb3YSZ4VFtg2Qt                                       Acoustic
# 1     1kJygfS4eoVziBBI93MSYp                                       Acoustic
# 2     6lynns69p4zTCRxmmiSY1x                  Here Comes the Sun - Acoustic
# 3     1RC9slv335IfLce5vt9KTW                                    Acoustic #3
# 4     5o9L8xBuILoVjLECSBi7Vo  My Love Mine All Mine - Acoustic Instrumental
# ...                      ...                                            ...
# 6297  56pHPaTeX2O9aVmTFYS8hV                                   The Daintree
# 6298  6Ldyc5TsR4kaUsuHKcB2AD                         The Sorcerers Symphony
# 6299  3ry0f8ybk8upUBIk8unvmF                                Fiore d'inverno
# 6300                     NaN                                            NaN
# 6301                     NaN                                            NaN
#
#             genre                        artists  \
# ...

# %%
df4=df3.dropna(how='any')
df4
# Out:
#                           id                                           name  \
# 0     7kr3xZk4yb3YSZ4VFtg2Qt                                       Acoustic
# 1     1kJygfS4eoVziBBI93MSYp                                       Acoustic
# 2     6lynns69p4zTCRxmmiSY1x                  Here Comes the Sun - Acoustic
# 3     1RC9slv335IfLce5vt9KTW                                    Acoustic #3
# 4     5o9L8xBuILoVjLECSBi7Vo  My Love Mine All Mine - Acoustic Instrumental
# ...                      ...                                            ...
# 6295  4uveHSzaz8YEbTF9j6QlCI                             Voyage to Atlantis
# 6296  4u15cjyziW2Ewn5Ek3082l                                       L'Oiseau
# 6297  56pHPaTeX2O9aVmTFYS8hV                                   The Daintree
# 6298  6Ldyc5TsR4kaUsuHKcB2AD                         The Sorcerers Symphony
# 6299  3ry0f8ybk8upUBIk8unvmF                                Fiore d'inverno
#
# ...

# %%
import seaborn as sns

# %%
df4.to_csv('Spotify_cleaned',index=False)
